# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import glob as glob
import datetime as dt

import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.io import shapereader
import cartopy.io.img_tiles as cimgt

# %%
df = pd.read_csv("GHCND_Illinois_Stations.csv", index_col=0)

illinois = df

station_names = illinois["STATION_ID"].tolist()

# station_names

# %%
len(station_names)
# Out:
# 80

# %%
lons = illinois["LONGITUDE"].astype(float).values
lats = illinois["LATITUDE"].astype(float).values
names = illinois["STATION_NAME"].values

fig = plt.figure(figsize=(15, 10))
ax = plt.axes(projection=ccrs.PlateCarree())

ax.add_feature(cfeature.STATES.with_scale('10m'), edgecolor='black', facecolor='none')
ax.add_feature(cfeature.RIVERS.with_scale('10m'))
ax.add_feature(cfeature.LAKES.with_scale('10m'), alpha=0.5)

ax.scatter(lons, lats, s=20, marker='o', edgecolor='k', transform=ccrs.PlateCarree())

for lon, lat, name in zip(lons, lats, names):
    ax.text(lon + 0.05, lat + 0.05, name, fontsize=10,
            transform=ccrs.PlateCarree())

ax.set_extent([-92.8, -86.0, 36, 43.5], crs=ccrs.PlateCarree())

ax.set_title("Illinois Weather Stations that has data from 1940-2024")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[58], line 21
#      18 ax.set_extent([-92.8, -86.0, 36, 43.5], crs=ccrs.PlateCarree())
#      20 ax.set_title("Illinois Weather Stations that has data from 1940-2024")
# ---> 21 plt.show()
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/pyplot.py:527, in show(*args, **kwargs)
#     483 """
#     484 Display all open figures.
#     485
#    (...)
#     524 explicitly there.
#     525 """
#     526 _warn_if_gui_out_of_main_thread()
# --> 527 return _get_backend_mod().show(*args, **kwargs)
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/IPython/core/formatters.py:179, in DisplayFormatter.format(self, obj, include, exclude)
#     177 md = None
#     178 try:
# --> 179     data = formatter(obj)
#     180 except:
#     181     # FIXME: log the exception
#     182     raise
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/IPython/core/formatters.py:223, in catch_format_error(method, self, *args, **kwargs)
#     221 """show traceback on failed format call"""
#     222 try:
# --> 223     r = method(self, *args, **kwargs)
#     224 except NotImplementedError:
#     225     # don't warn on NotImplementedErrors
#     226     return self._check_return(None, args[0])
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/IPython/core/formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/backend_bases.py:2167, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2165 if bbox_inches:
#    2166     if bbox_inches == "tight":
# -> 2167         bbox_inches = self.figure.get_tightbbox(
#    2168             renderer, bbox_extra_artists=bbox_extra_artists)
#    2169         if (isinstance(layout_engine, ConstrainedLayoutEngine) and
#    2170                 pad_inches == "layout"):
#    2171             h_pad = layout_engine.get()["h_pad"]
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/figure.py:1783, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    1779 if ax.get_visible():
#    1780     # some axes don't take the bbox_extra_artists kwarg so we
#    1781     # need this conditional....
#    1782     try:
# -> 1783         bbox = ax.get_tightbbox(
#    1784             renderer, bbox_extra_artists=bbox_extra_artists)
#    1785     except TypeError:
#    1786         bbox = ax.get_tightbbox(renderer)
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/cartopy/mpl/geoaxes.py:499, in GeoAxes.get_tightbbox(self, renderer, *args, **kwargs)
#     496 # Shared processing steps
#     497 self._draw_preprocess(renderer)
# --> 499 return super().get_tightbbox(renderer, *args, **kwargs)
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/axes/_base.py:4418, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4415     bbox_artists = self.get_default_bbox_extra_artists()
#    4417 for a in bbox_artists:
# -> 4418     bbox = a.get_tightbbox(renderer)
#    4419     if (bbox is not None
#    4420             and 0 < bbox.width < np.inf
#    4421             and 0 < bbox.height < np.inf):
#    4422         bb.append(bbox)
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/artist.py:366, in Artist.get_tightbbox(self, renderer)
#     350 def get_tightbbox(self, renderer=None):
#     351     """
#     352     Like `.Artist.get_window_extent`, but includes any clipping.
#     353
#    (...)
#     364         Returns None if clipping results in no intersection.
#     365     """
# --> 366     bbox = self.get_window_extent(renderer)
#     367     if self.get_clip_on():
#     368         clip_box = self.get_clip_box()
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/text.py:956, in Text.get_window_extent(self, renderer, dpi)
#     951     raise RuntimeError(
#     952         "Cannot get window extent of text w/o renderer. You likely "
#     953         "want to call 'figure.draw_without_rendering()' first.")
#     955 with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 956     bbox, info, descent = self._get_layout(self._renderer)
#     957     x, y = self.get_unitless_position()
#     958     x, y = self.get_transform().transform((x, y))
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/text.py:381, in Text._get_layout(self, renderer)
#     379 clean_line, ismath = self._preprocess_math(line)
#     380 if clean_line:
# --> 381     w, h, d = _get_text_metrics_with_cache(
#     382         renderer, clean_line, self._fontproperties,
#     383         ismath=ismath, dpi=self.figure.dpi)
#     384 else:
#     385     w = h = d = 0
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/text.py:69, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#      66 """Call ``renderer.get_text_width_height_descent``, caching the results."""
#      67 # Cached based on a copy of fontprop so that later in-place mutations of
#      68 # the passed-in argument do not mess up the cache.
# ---> 69 return _get_text_metrics_with_cache_impl(
#      70     weakref.ref(renderer), text, fontprop.copy(), ismath, dpi)
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/text.py:77, in _get_text_metrics_with_cache_impl(renderer_ref, text, fontprop, ismath, dpi)
#      73 @functools.lru_cache(4096)
#      74 def _get_text_metrics_with_cache_impl(
#      75         renderer_ref, text, fontprop, ismath, dpi):
#      76     # dpi is unused, but participates in cache invalidation (via the renderer).
# ---> 77     return renderer_ref().get_text_width_height_descent(text, fontprop, ismath)
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:221, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     218     return width, height, descent
#     220 font = self._prepare_font(prop)
# --> 221 font.set_text(s, 0.0, flags=get_hinting_flag())
#     222 w, h = font.get_width_height()  # width and height of unrotated string
#     223 d = font.get_descent()
#
# KeyboardInterrupt:

# %%
illinois["STATION_ID_MOD"] = (
    illinois["STATION_ID"]
      .str.replace("GHCND", "GHCNh", regex=False)
      .str.replace(":", "_",    regex=False)
)

# %%
station_ids = illinois["STATION_ID_MOD"].to_list()

# %%
station_ids
# Out:
# ['GHCNh_ASN00008119',
#  'GHCNh_USC00428465',
#  'GHCNh_ASN00014910',
#  'GHCNh_BR001065002',
#  'GHCNh_CA005012545',
#  'GHCNh_US1CAMA0005',
#  'GHCNh_CA008401251',
#  'GHCNh_US1TNRD0108',
#  'GHCNh_USC00099506',
#  'GHCNh_USC00503205',
#  'GHCNh_US1FLLE0041',
#  'GHCNh_US1OHMY0021',
#  'GHCNh_USC00043928',
#  'GHCNh_US1MIVB0004',
#  'GHCNh_US1NCGN0007',
#  'GHCNh_ASN00075026',
#  'GHCNh_USC00044259',
#  'GHCNh_IN004010501',
#  'GHCNh_US1WAWC0036',
#  'GHCNh_US1NMOT0040',
#  'GHCNh_ASN00020042',
#  'GHCNh_SWE00138090',
#  'GHCNh_ASN00091155',
#  'GHCNh_RSM00029612',
#  'GHCNh_US1TNRD0020',
#  'GHCNh_US1NMSN0054',
#  'GHCNh_BR002754010',
#  'GHCNh_US1COGF0054',
#  'GHCNh_US1WYSW0014',
#  'GHCNh_USR0000CROC',
#  'GHCNh_USC00361581',
#  'GHCNh_MXN00024043',
#  'GHCNh_US1KSCQ0002',
#  'GHCNh_USC00337925',
#  'GHCNh_US1NCWK0155',
#  'GHCNh_BF1SE000001',
#  'GHCNh_FIE00144387',
#  'GHCNh_MXN00012153',
#  'GHCNh_US1TXTV0273',
#  'GHCNh_US1MNDK0036',
#  'GHCNh_GME00122746',
#  'GHCNh_USC00270215',
#  'GHCNh_SWE00139258',
#  'GHCNh_BR000661000',
#  'GHCNh_CA001030600',
#  'GHCNh_SF002528940',
#  'GHCNh_CA005021849',
#  'GHCNh_CA006104146',
#  'GHCNh_MXM00076458',
#  'GHCNh_BR002956002',
#  'GHCNh_USC00353402',
#  'GHCNh_US10chas012',
#  'GHCNh_MXN00011140',
#  'GHCNh_USC00316231',
#  'GHCNh_US10adam019',
#  'GHCNh_IN009070900',
#  'GHCNh_CA1ON000145',
#  'GHCNh_US1AZMR0023',
#  'GHCNh_US10sarp032',
#  'GHCNh_US1TXBEL061',
#  'GHCNh_ASN00008239',
#  'GHCNh_US1PACB0020',
#  'GHCNh_ASN00076022',
#  'GHCNh_MXN00030032',
#  'GHCNh_MXN00008322',
#  'GHCNh_ASN00087070',
#  'GHCNh_US1NJES0019',
#  'GHCNh_MXN00008118',
#  'GHCNh_US1TXWA0009',
#  'GHCNh_US1KSHV0027',
#  'GHCNh_USC00460307',
#  'GHCNh_US1NYDT0039',
#  'GHCNh_USC00050370',
#  'GHCNh_USC00314689',
#  'GHCNh_USC00344915',
#  'GHCNh_US1SDMC0011',
#  'GHCNh_CA003073673',
#  'GHCNh_ASN00009857',
#  'GHCNh_ASN00044217',
#  'GHCNh_BR00B8-0090',
#  'GHCNh_US1TNOV0001',
#  'GHCNh_US1INDK0013',
#  'GHCNh_SWE00137502',
#  'GHCNh_GME00131410',
#  'GHCNh_UKE00105907',
#  'GHCNh_USC00168861',
#  'GHCNh_BR00D3-0320',
#  'GHCNh_GMM00010433',
#  'GHCNh_USC00024586',
#  'GHCNh_ASN00066155',
#  'GHCNh_MXN00008077',
#  'GHCNh_CA004023520',
#  'GHCNh_US1COLA0010',
#  'GHCNh_US1NMSJ0054',
#  'GHCNh_BR00E3-0280',
#  'GHCNh_RSM00020674',
#  'GHCNh_CA1ON000164',
#  'GHCNh_US1ALBW0068',
#  'GHCNh_US1NCCM0040',
#  'GHCNh_ASN00088138',
#  'GHCNh_BR000643011',
#  'GHCNh_ASN00033119',
#  'GHCNh_ASN00092128',
#  'GHCNh_USC00418640',
#  'GHCNh_US1FLMR0061',
#  'GHCNh_US1KYGT0002',
#  'GHCNh_US1SDGY0028',
#  'GHCNh_FMC00914665',
#  'GHCNh_TH000048450',
#  'GHCNh_US1COEP0069',
#  'GHCNh_FIE00145587',
#  'GHCNh_US1WAKL0005',
#  'GHCNh_CA006119500',
#  'GHCNh_ASN00073004',
#  'GHCNh_US1TXCLL094',
#  'GHCNh_USC00045823',
#  'GHCNh_CA001092490',
#  'GHCNh_CA003073740',
#  'GHCNh_USC00410436',
#  'GHCNh_ASN00010747',
#  'GHCNh_BR002752004',
#  'GHCNh_USC00487236',
#  'GHCNh_US1SCHR0046',
#  'GHCNh_US1SDLW0022',
#  'GHCNh_US1COLR0494',
#  'GHCNh_US1COGR0005',
#  'GHCNh_US1ARLG0004',
#  'GHCNh_US1MTMD0002',
#  'GHCNh_US1NCNH0088',
#  'GHCNh_US1KYPW0001',
#  'GHCNh_US1INOR0027',
#  'GHCNh_USC00029223',
#  'GHCNh_USC00103345',
#  'GHCNh_USC00185201',
#  'GHCNh_USC00515756',
#  'GHCNh_US1NMSC0060',
#  'GHCNh_USC00382080',
#  'GHCNh_USC00431730',
#  'GHCNh_US1KSMP0016',
#  'GHCNh_USW00023233',
#  'GHCNh_MXN00030468',
#  'GHCNh_BR038150640',
#  'GHCNh_USC00210195',
#  'GHCNh_GM000004063',
#  'GHCNh_US1VAAB0010',
#  'GHCNh_WA005700880',
#  'GHCNh_SWE00139106',
#  'GHCNh_CA0010551R8',
#  'GHCNh_US1AZPM0174',
#  'GHCNh_US1SDYN0008',
#  'GHCNh_US1TXJS0006',
#  'GHCNh_US1SCKR0045',
#  'GHCNh_BR000748001',
#  'GHCNh_US1CANV0006',
#  'GHCNh_ASN00040899',
#  'GHCNh_ASN00091159',
#  'GHCNh_ASN00040796',
#  'GHCNh_ASN00031161',
#  'GHCNh_USC00300772',
#  'GHCNh_US1CODG0221',
#  'GHCNh_MXN00013148',
#  'GHCNh_CA007020835',
#  'GHCNh_US1ALMN0002',
#  'GHCNh_ASN00040014',
#  'GHCNh_US1ILGL0002',
#  'GHCNh_US1TXHRR238',
#  'GHCNh_US1MNSH0039',
#  'GHCNh_CA004083720',
#  'GHCNh_FIE00145417',
#  'GHCNh_US1TXBXR006',
#  'GHCNh_USC00221962',
#  'GHCNh_GME00126958',
#  'GHCNh_USC00361209',
#  'GHCNh_IN018102100',
#  'GHCNh_ASN00042050',
#  'GHCNh_USR0000MPRY',
#  'GHCNh_USR0000SNEM',
#  'GHCNh_RSM00026393',
#  'GHCNh_USC00202472',
#  'GHCNh_IN003050301',
#  'GHCNh_US1AZMR0266',
#  'GHCNh_CA006159125',
#  'GHCNh_US1MIMY0003',
#  'GHCNh_US1INNB0013',
#  'GHCNh_US1COJF0039',
#  'GHCNh_USC00417729',
#  'GHCNh_US1ORCS0003',
#  'GHCNh_US1TXGS0031',
#  'GHCNh_SWE00140154',
#  'GHCNh_USC00292593',
#  'GHCNh_US1KYAN0007',
#  'GHCNh_US1INDL0030',
#  'GHCNh_US1NJCD0018',
#  'GHCNh_USC00045903',
#  'GHCNh_US1TXHRR176',
#  'GHCNh_US1SDTP0013',
#  'GHCNh_US1NMVL0033',
#  'GHCNh_SF002284580',
#  'GHCNh_US1OHDL0008',
#  'GHCNh_MXN00005175',
#  'GHCNh_USC00010762',
#  'GHCNh_US1COCU0019',
#  'GHCNh_US1PACF0002',
#  'GHCNh_IN001100601',
#  'GHCNh_US1SCCR0008',
#  'GHCNh_CA1ON000418',
#  'GHCNh_ASN00055240',
#  'GHCNh_USW00024252',
#  'GHCNh_IN011130900',
#  'GHCNh_USC00509902',
#  'GHCNh_CA002400602',
#  'GHCNh_US1ILMP0010',
#  'GHCNh_ASN00010221',
#  'GHCNh_UKE00115811',
#  'GHCNh_MXN00032184',
#  'GHCNh_BR038630760',
#  'GHCNh_CA007025442',
#  'GHCNh_RSM00022318',
#  'GHCNh_MXN00007206',
#  'GHCNh_SF006787760',
#  'GHCNh_IN019130600',
#  'GHCNh_USC00124918',
#  'GHCNh_USC00044144',
#  'GHCNh_USC00045909',
#  'GHCNh_US1INHM0032',
#  'GHCNh_US1COBO0329',
#  'GHCNh_USC00354632',
#  'GHCNh_CA004060790',
#  'GHCNh_US1NCCS0008',
#  'GHCNh_US1WAMS0007',
#  'GHCNh_IN009011600',
#  'GHCNh_ASN00047002',
#  'GHCNh_CA1ON000545',
#  'GHCNh_US1FLCB0018',
#  'GHCNh_US1WIIR0002',
#  'GHCNh_SF007175950',
#  'GHCNh_US1NCNR0007',
#  'GHCNh_FIE00145151',
#  'GHCNh_US1GACT0002',
#  'GHCNh_UPM00033518',
#  'GHCNh_US10furn009',
#  'GHCNh_US1NYOG0038',
#  'GHCNh_US1NJMS0074',
#  'GHCNh_CA007041166',
#  'GHCNh_US1TXCLB003',
#  'GHCNh_US1ARPL0007',
#  'GHCNh_BR00D2-0410',
#  'GHCNh_US1TNSH0027',
#  'GHCNh_ASN00040158',
#  'GHCNh_ASN00086091',
#  'GHCNh_MXN00014129',
#  'GHCNh_US1WASG0023',
#  'GHCNh_RSM00029587',
#  'GHCNh_AJ000037835',
#  'GHCNh_UPM00034717',
#  'GHCNh_MXN00025073',
#  'GHCNh_MXN00013098',
#  'GHCNh_USC00233375',
#  'GHCNh_ASN00018125',
#  'GHCNh_ASN00010689',
#  'GHCNh_IN023480300',
#  'GHCNh_US1CASC0004',
#  'GHCNh_IN017070501',
#  'GHCNh_ASN00046076',
#  'GHCNh_USC00310438',
#  'GHCNh_USC00472507',
#  'GHCNh_ASN00066152',
#  'GHCNh_JA000047616',
#  'GHCNh_US1TXGG0015',
#  'GHCNh_MXN00011154',
#  'GHCNh_MXN00011124',
#  'GHCNh_US1ALTS0003',
#  'GHCNh_ASN00040623',
#  'GHCNh_ASN00069078',
#  'GHCNh_US10chey028',
#  'GHCNh_BR038690570',
#  'GHCNh_MXN00013091',
#  'GHCNh_IN013011400',
#  'GHCNh_USC00144589',
#  'GHCNh_USC00262510',
#  'GHCNh_US1SDMH0105',
#  'GHCNh_KZ000035467',
#  'GHCNh_US1COBO0351',
#  'GHCNh_ASN00045005',
#  'GHCNh_USC00158070',
#  'GHCNh_USC00227141',
#  'GHCNh_CA003034552',
#  'GHCNh_BR038616720',
#  'GHCNh_RSM00029848',
#  'GHCNh_BR038332350',
#  'GHCNh_IRM00040736',
#  'GHCNh_US1SCHR0111',
#  'GHCNh_ASN00070158',
#  'GHCNh_GG000037328',
#  'GHCNh_CA003016494',
#  'GHCNh_US1CAMR0001',
#  'GHCNh_US1INMG0008',
#  'GHCNh_USC00203529',
#  'GHCNh_US1NMBR0196',
#  'GHCNh_USC00308635',
#  'GHCNh_US1TNMM0002',
#  'GHCNh_USS0019E03S',
#  'GHCNh_US1AZPM0247',
#  'GHCNh_US1INSJ0047',
#  'GHCNh_USC00306523',
#  'GHCNh_BR047960130',
#  'GHCNh_ASN00087023',
#  'GHCNh_US1WAKG0226',
#  'GHCNh_IN019191500',
#  'GHCNh_USC00484303',
#  'GHCNh_ASN00039171',
#  'GHCNh_MXN00006004',
#  'GHCNh_USR0000MGAT',
#  'GHCNh_US1COLP0026',
#  'GHCNh_MXN00012104',
#  'GHCNh_ASN00080088',
#  'GHCNh_US1INSL0002',
#  'GHCNh_US1MNWD0001',
#  'GHCNh_ASN00032130',
#  'GHCNh_IN005061700',
#  'GHCNh_ASN00012077',
#  'GHCNh_GM000003038',
#  'GHCNh_US1OHSC0006',
#  'GHCNh_USC00053538',
#  'GHCNh_US1DEKN0013',
#  'GHCNh_BR003052016',
#  'GHCNh_ASN00012076',
#  'GHCNh_CA003052745',
#  'GHCNh_BR047697620',
#  'GHCNh_ASN00063246',
#  'GHCNh_US1SCGV0097',
#  'GHCNh_US1TXBRT077',
#  'GHCNh_USC00406479',
#  'GHCNh_USC00223671',
#  'GHCNh_BR002048013',
#  'GHCNh_CA00702607F',
#  'GHCNh_BR00C5-0260',
#  'GHCNh_USW00073805',
#  'GHCNh_AJ000037673',
#  'GHCNh_CA001017575',
#  'GHCNh_US1IAHN0002',
#  'GHCNh_MXN00026123',
#  'GHCNh_BR048916560',
#  'GHCNh_US1COLP0110',
#  'GHCNh_USC00208422',
#  'GHCNh_US1MNSC0037',
#  'GHCNh_GMW00034056',
#  'GHCNh_ASN00012017',
#  'GHCNh_USC00114465',
#  'GHCNh_MXN00016197',
#  'GHCNh_SF000292970',
#  'GHCNh_USC00243013',
#  'GHCNh_MAM00067017',
#  'GHCNh_ASN00033177',
#  'GHCNh_ASN00024027',
#  'GHCNh_US1TXBRT106',
#  'GHCNh_US1ORWS0084',
#  'GHCNh_USC00247156',
#  'GHCNh_US1LATG0017',
#  'GHCNh_BR038492540',
#  'GHCNh_CA005012931',
#  'GHCNh_USC00051018',
#  'GHCNh_US1COCU0006',
#  'GHCNh_IN019211300',
#  'GHCNh_RSM00027928',
#  'GHCNh_US1ARGL0016',
#  'GHCNh_USC00118750',
#  'GHCNh_USC00502952',
#  'GHCNh_US1AZPM0199',
#  'GHCNh_USC00352440',
#  'GHCNh_CA006109515',
#  'GHCNh_USC00441375',
#  'GHCNh_ASN00092046',
#  'GHCNh_ASN00040316',
#  'GHCNh_USC00455664',
#  'GHCNh_USC00413415',
#  'GHCNh_USC00102875',
#  'GHCNh_BR002244066',
#  'GHCNh_ASN00035202',
#  'GHCNh_US1WADG0001',
#  'GHCNh_CA007083620',
#  'GHCNh_US1NCBF0030',
#  'GHCNh_US1NCCC0003',
#  'GHCNh_US1GAEL0005',
#  'GHCNh_US1COMZ0059',
#  'GHCNh_USC00117004',
#  'GHCNh_GR000016754',
#  'GHCNh_CA001040909',
#  'GHCNh_ASN00002033',
#  'GHCNh_CA002101601',
#  'GHCNh_CA1ON000313',
#  'GHCNh_US1SCLX0063',
#  'GHCNh_US1MNGR0011',
#  'GHCNh_IN012160700',
#  'GHCNh_SF002621290',
#  'GHCNh_USC00519475',
#  'GHCNh_USC00415211',
#  'GHCNh_ASN00025520',
#  'GHCNh_CA008200989',
#  'GHCNh_CHM00056096',
#  'GHCNh_FIE00146787',
#  'GHCNh_IN001113300',
#  'GHCNh_US1NMSF0057',
#  'GHCNh_JA000047677',
#  'GHCNh_US1MDWH0010',
#  'GHCNh_US1VAVBC013',
#  'GHCNh_ASN00083066',
#  'GHCNh_ASN00050016',
#  'GHCNh_GLE00147558',
#  'GHCNh_CA007044460',
#  'GHCNh_GME00131398',
#  'GHCNh_USC00478978',
#  'GHCNh_ASN00098012',
#  'GHCNh_US1NCCN0046',
#  'GHCNh_ASN00039331',
#  'GHCNh_US1MNNC0002',
#  'GHCNh_CA001149000',
#  'GHCNh_NIM00065271',
#  'GHCNh_MXN00027037',
#  'GHCNh_US1TNFK0008',
#  'GHCNh_USS0005M16S',
#  'GHCNh_USC00112679',
#  'GHCNh_US1NMBR0316',
#  'GHCNh_USC00283102',
#  'GHCNh_BR00C4-0890',
#  'GHCNh_US1FLPB0019',
#  'GHCNh_BR002147034',
#  'GHCNh_MGM00044207',
#  'GHCNh_ASN00025560',
#  'GHCNh_USC00169444',
#  'GHCNh_USC00473198',
#  'GHCNh_CA1ON000415',
#  'GHCNh_MXN00020206',
#  'GHCNh_USW00094946',
#  'GHCNh_CA001192950',
#  'GHCNh_US1CALA0097',
#  'GHCNh_US1ILGY0001',
#  'GHCNh_ASN00068123',
#  'GHCNh_USW00023246',
#  'GHCNh_USC00478639',
#  'GHCNh_US1WAKP0021',
#  'GHCNh_US1TXMCL058',
#  'GHCNh_US1VANNC016',
#  'GHCNh_SWE00140932',
#  'GHCNh_EIM00003955',
#  'GHCNh_USC00054242',
#  'GHCNh_ASN00086067',
#  'GHCNh_ASN00061080',
#  'GHCNh_US1ILHM0002',
#  'GHCNh_CA003053760',
#  'GHCNh_USR0000AFPK',
#  'GHCNh_IN020120700',
#  'GHCNh_IN004033700',
#  'GHCNh_IN012201200',
#  'GHCNh_ASN00014964',
#  'GHCNh_US1TXJW0007',
#  'GHCNh_US1NMGR0045',
#  'GHCNh_SWE00139158',
#  'GHCNh_USC00084667',
#  'GHCNh_US1FLSL0029',
#  'GHCNh_USC00188380',
#  'GHCNh_ASN00023830',
#  'GHCNh_BR002551024',
#  'GHCNh_CA003025920',
#  'GHCNh_GME00124930',
#  'GHCNh_US1WYWS0003',
#  'GHCNh_USC00514762',
#  'GHCNh_AR000087217',
#  'GHCNh_USC00229400',
#  'GHCNh_NLE00109008',
#  'GHCNh_ASN00009267',
#  'GHCNh_ASN00066025',
#  'GHCNh_CA001031316',
#  'GHCNh_USC00394651',
#  'GHCNh_USC00208746',
#  'GHCNh_US1NVCK0029',
#  'GHCNh_USW00092809',
#  'GHCNh_US1TNMT0003',
#  'GHCNh_US1ILCK0094',
#  'GHCNh_ASN00014096',
#  'GHCNh_UPM00033976',
#  'GHCNh_MXN00015048',
#  'GHCNh_USR0000CJAY',
#  'GHCNh_CA006044000',
#  'GHCNh_US1TXTV0302',
#  'GHCNh_US1NCPK0028',
#  'GHCNh_US1SCYR0023',
#  'GHCNh_US1SCOC0018',
#  'GHCNh_ASN00055136',
#  'GHCNh_ASN00063127',
#  'GHCNh_US1CALA0048',
#  'GHCNh_US1FLWK0010',
#  'GHCNh_MXN00030199',
#  'GHCNh_ASN00017014',
#  'GHCNh_RSM00031909',
#  'GHCNh_US10webs018',
#  'GHCNh_USC00392888',
#  'GHCNh_ASN00010850',
#  'GHCNh_USC00107721',
#  'GHCNh_US1TXBXR136',
#  'GHCNh_USC00458694',
#  'GHCNh_US1NYBM0034',
#  'GHCNh_US1TXBST127',
#  'GHCNh_ASN00041361',
#  'GHCNh_US1MDAA0059',
#  'GHCNh_US1ORCT0022',
#  'GHCNh_MXN00030015',
#  'GHCNh_USC00130181',
#  'GHCNh_US1WYSL0001',
#  'GHCNh_US1AZCN0149',
#  'GHCNh_US1CARV0060',
#  'GHCNh_US1MNCN0001',
#  'GHCNh_US1TNWS0001',
#  'GHCNh_US1CASD0022',
#  'GHCNh_SWE00139044',
#  'GHCNh_CA001075200',
#  'GHCNh_US1SCLX0096',
#  'GHCNh_KSM00047133',
#  'GHCNh_GME00123178',
#  'GHCNh_USC00132041',
#  'GHCNh_NLE00109388',
#  'GHCNh_ASN00009955',
#  'GHCNh_MXN00020037',
#  'GHCNh_IN001112300',
#  'GHCNh_ASN00086336',
#  'GHCNh_ASN00025510',
#  'GHCNh_GME00124978',
#  'GHCNh_US1OKTL0080',
#  'GHCNh_BR038447030',
#  'GHCNh_US1NYCM0006',
#  'GHCNh_USC00120550',
#  'GHCNh_USC00146292',
#  'GHCNh_US1KYSC0023',
#  'GHCNh_US1WIDA0087',
#  'GHCNh_US1NMCT0019',
#  'GHCNh_CA005012942',
#  'GHCNh_ASN00010802',
#  'GHCNh_USC00488868',
#  'GHCNh_IN009171000',
#  'GHCNh_CA001197860',
#  'GHCNh_IN017011000',
#  'GHCNh_MXN00020155',
#  'GHCNh_US1WIWK0057',
#  'GHCNh_USC00115384',
#  'GHCNh_USS0021C17S',
#  'GHCNh_CA1AB000093',
#  'GHCNh_US1KSNS0003',
#  'GHCNh_ASN00009764',
#  'GHCNh_RSM00034625',
#  'GHCNh_USC00468083',
#  'GHCNh_MXN00016135',
#  'GHCNh_US1MTRB0014',
#  'GHCNh_US1MOMT0002',
#  'GHCNh_ASN00048082',
#  'GHCNh_BR037750120',
#  'GHCNh_US1PASM0006',
#  'GHCNh_US1KSDK0001',
#  'GHCNh_US1KSEL0034',
#  'GHCNh_US1NCRW0016',
#  'GHCNh_USC00036856',
#  'GHCNh_USC00402589',
#  'GHCNh_CA002400802',
#  'GHCNh_USC00417981',
#  'GHCNh_US1NVWH0089',
#  'GHCNh_USC00125342',
#  'GHCNh_BR002244075',
#  'GHCNh_IN001063800',
#  'GHCNh_US1ALMD0059',
#  'GHCNh_US1NMSC0049',
#  'GHCNh_US1ILGY0027',
#  'GHCNh_USC00107648',
#  'GHCNh_US1AZMH0003',
#  'GHCNh_US1MDKN0008',
#  'GHCNh_IN007040100',
#  'GHCNh_USR0000AWLL',
#  'GHCNh_USC00487260',
#  'GHCNh_USC00348587',
#  'GHCNh_VQC00670480',
#  'GHCNh_UG000063684',
#  'GHCNh_BR038534990',
#  'GHCNh_ASN00082140',
#  'GHCNh_US1MDCH0014',
#  'GHCNh_MXN00002036',
#  'GHCNh_US1NCCS0002',
#  'GHCNh_US1ILLV0012',
#  'GHCNh_USC00148061',
#  'GHCNh_USR0000UPRC',
#  'GHCNh_US1INLW0011',
#  'GHCNh_USC00253710',
#  'GHCNh_US1CASC0045',
#  'GHCNh_US1NMBR0017',
#  'GHCNh_USC00318906',
#  'GHCNh_US1NCCM0013',
#  'GHCNh_US1ILRC0005',
#  'GHCNh_US1ALMY0001',
#  'GHCNh_ASN00041049',
#  'GHCNh_US1KSLC0005',
#  'GHCNh_SWE00140694',
#  'GHCNh_US1SDCR0005',
#  'GHCNh_SWE00137828',
#  'GHCNh_US1MNSR0048',
#  'GHCNh_ASN00019028',
#  'GHCNh_US1TXWM0278',
#  'GHCNh_US1ILCK0331',
#  'GHCNh_BR00C8-0430',
#  'GHCNh_ASN00008131',
#  'GHCNh_US1MNLQ0004',
#  'GHCNh_US1WYBH0008',
#  'GHCNh_US1MOCW0005',
#  'GHCNh_US1WYCK0026',
#  'GHCNh_US1AZYV0091',
#  'GHCNh_USC00035562',
#  'GHCNh_USC00029007',
#  'GHCNh_US1MOPT0009',
#  'GHCNh_USC00103297',
#  'GHCNh_CA001090990',
#  'GHCNh_RSM00022355',
#  'GHCNh_MXN00015330',
#  'GHCNh_BR00E6-0160',
#  'GHCNh_IN011030900',
#  'GHCNh_ASN00053046',
#  'GHCNh_US1TXBRT005',
#  'GHCNh_ASN00097013',
#  'GHCNh_MXN00015383',
#  'GHCNh_USC00124181',
#  'GHCNh_US1MODT0013',
#  'GHCNh_USC00368657',
#  'GHCNh_US1COEP0247',
#  'GHCNh_USC00500653',
#  'GHCNh_US1SCBF0078',
#  'GHCNh_MXN00013112',
#  'GHCNh_US1INMR0103',
#  'GHCNh_SF001186400',
#  'GHCNh_ASN00048242',
#  'GHCNh_US1MAMD0035',
#  'GHCNh_USC00037383',
#  'GHCNh_US1NMDA0196',
#  ...]

# %%
import requests
from io import StringIO
import sys

# %%
station_ids[0]
# Out:
# 'GHCNh_USC00113879'

# %%
base_url = "https://www.ncei.noaa.gov/oa/global-historical-climatology-network/index.html#hourly/access/by-station"

data_by_station = {}
sorted_station_ids = []

for i, sid in enumerate(station_ids):
    url = f"{base_url}/{sid}_por.psv"
    try:
        r = requests.get(url)
        r.raise_for_status() 
    except requests.HTTPError as e:
        print(f"Failed to fetch {sid}: {e}")
        continue

    
    #df = pd.read_csv(StringIO(r.text), sep="|")
    #data_by_station[sid] = df
    sorted_station_ids.append(sid)

# %%
len(sorted_station_ids)
# Out:
# 32

# %%
sorted_station_ids[15]
# Out:
# 'GHCNh_USC00114317'

# %%
base_url = "https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station"

data_by_station = []

for i, sid in enumerate(sorted_station_ids):
    url = f"{base_url}/{sid}_por.psv"
    try:
        r = requests.get(url)
        r.raise_for_status() 
    except requests.HTTPError as e:
        print(f"Failed to fetch {sid}: {e}")
        continue

    df = pd.read_csv(StringIO(r.text), sep="|", low_memory=False)
    data_by_station.append(df)
    print(f"success: {sid}")
# Out:
# Failed to fetch GHCNh_USC00116642: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00116642_por.psv
# success: GHCNh_USC00110583
# success: GHCNh_USC00110082
# Failed to fetch GHCNh_USC00118870: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00118870_por.psv
# success: GHCNh_USC00117014
# success: GHCNh_USC00113879
# success: GHCNh_USC00115079
# success: GHCNh_USW00014834
# success: GHCNh_USC00115983
# Failed to fetch GHCNh_USC00117354: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00117354_por.psv
# Failed to fetch GHCNh_USC00116973: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00116973_por.psv
# Failed to fetch GHCNh_USC00117157: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00117157_por.psv
# Failed to fetch GHCNh_USC00111700: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00111700_por.psv
# success: GHCNh_USC00112687
# Failed to fetch GHCNh_USC00116765: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00116765_por.psv
# success: GHCNh_USC00114317
# success: GHCNh_USC00117391
# success: GHCNh_USC00111302
# Failed to fetch GHCNh_USC00113940: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00113940_por.psv
# Failed to fetch GHCNh_USC00111475: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00111475_por.psv
# Failed to fetch GHCNh_USC00118630: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00118630_por.psv
# Failed to fetch GHCNh_USC00116753: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00116753_por.psv
# Failed to fetch GHCNh_USC00129112: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00129112_por.psv
# Failed to fetch GHCNh_USC00113312: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00113312_por.psv
# Failed to fetch GHCNh_USC00112931: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00112931_por.psv
# Failed to fetch GHCNh_USC00111386: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00111386_por.psv
# Failed to fetch GHCNh_USC00113335: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00113335_por.psv
# Failed to fetch GHCNh_USC00117345: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00117345_por.psv
# success: GHCNh_USW00093809
# Failed to fetch GHCNh_USC00116769: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00116769_por.psv
# success: GHCNh_USC00111290
# success: GHCNh_USC00113666
# Failed to fetch GHCNh_USC00117859: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00117859_por.psv
# Failed to fetch GHCNh_USC00110993: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00110993_por.psv
# Failed to fetch GHCNh_USC00111436: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00111436_por.psv
# Failed to fetch GHCNh_USC00112145: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00112145_por.psv
# success: GHCNh_USC00112923
# Failed to fetch GHCNh_USC00117551: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00117551_por.psv
# Failed to fetch GHCNh_USC00116663: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00116663_por.psv
# success: GHCNh_USC00118916
# Failed to fetch GHCNh_USC00112483: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00112483_por.psv
# success: GHCNh_USC00111743
# Failed to fetch GHCNh_USC00118293: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00118293_por.psv
# Failed to fetch GHCNh_USC00111265: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00111265_por.psv
# success: GHCNh_USC00112193
# Failed to fetch GHCNh_USC00118932: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00118932_por.psv
# success: GHCNh_USC00115493
# Failed to fetch GHCNh_USC00116011: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00116011_por.psv
# Failed to fetch GHCNh_USC00116490: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00116490_por.psv
# Failed to fetch GHCNh_USC00116874: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00116874_por.psv
# Failed to fetch GHCNh_USC00115326: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00115326_por.psv
# success: GHCNh_USC00114879
# Failed to fetch GHCNh_USC00114089: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00114089_por.psv
# Failed to fetch GHCNh_USC00118248: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00118248_por.psv
# Failed to fetch GHCNh_USC00113384: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00113384_por.psv
# Failed to fetch GHCNh_USC00111497: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00111497_por.psv
# success: GHCNh_USC00115841
# Failed to fetch GHCNh_USC00116558: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00116558_por.psv
# success: GHCNh_USC00111664
# success: GHCNh_USC00112353
# success: GHCNh_USC00119021
# Failed to fetch GHCNh_USC00117916: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00117916_por.psv
# success: GHCNh_USC00115768
# Failed to fetch GHCNh_USC00116910: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00116910_por.psv
# success: GHCNh_USW00014806
# Failed to fetch GHCNh_USC00113693: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00113693_por.psv
# success: GHCNh_USC00111577
# success: GHCNh_USC00117187
# Failed to fetch GHCNh_USC00114739: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00114739_por.psv
# Failed to fetch GHCNh_USC00115430: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00115430_por.psv
# success: GHCNh_USC00114805
# Failed to fetch GHCNh_USC00115935: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00115935_por.psv
# success: GHCNh_USC00118781
# Failed to fetch GHCNh_USC00115539: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00115539_por.psv
# Failed to fetch GHCNh_USC00110598: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00110598_por.psv
# Failed to fetch GHCNh_USC00114108: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00114108_por.psv
# Failed to fetch GHCNh_USC00115917: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00115917_por.psv
# success: GHCNh_USC00114198
# success: GHCNh_USC00112140
# Failed to fetch GHCNh_USC00116661: 404 Client Error: Not Found for url: https://www.ncei.noaa.gov/oa/global-historical-climatology-network/hourly/access/by-station/GHCNh_USC00116661_por.psv

# %%
len(data_by_station)
# Out:
# 32

# %%
data_by_station[0]['dew_point_temperature']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 576330   NaN
# 576331   NaN
# 576332   NaN
# 576333   NaN
# 576334   NaN
# Name: dew_point_temperature, Length: 576335, dtype: float64

# %%
with open(f"GHCNh_USC00113879_por.psv", "w", encoding="utf-8") as f:
    f.write(r.text)

# %%
data_by_station[i]
# Out:
#          Station_ID Station_name  Year  Month  Day  Hour  Minute  Latitude  \
# 0       USC00112140     DANVILLE  1951      5    2    19       0   40.1391
# 1       USC00112140     DANVILLE  1951      5    2    20       0   40.1391
# 2       USC00112140     DANVILLE  1951      5    2    21       0   40.1391
# 3       USC00112140     DANVILLE  1951      5    2    22       0   40.1391
# 4       USC00112140     DANVILLE  1951      5    2    23       0   40.1391
# ...             ...          ...   ...    ...  ...   ...     ...       ...
# 592558  USC00112140     DANVILLE  2022      1    1     2       0   40.1391
# 592559  USC00112140     DANVILLE  2022      1    1     3       0   40.1391
# 592560  USC00112140     DANVILLE  2022      1    1     4       0   40.1391
# 592561  USC00112140     DANVILLE  2022      1    1     5       0   40.1391
# 592562  USC00112140     DANVILLE  2022      1    1     6       0   40.1391
#
#         Longitude  Elevation  ...  precipitation_24_hour_Quality_Code  \
# 0        -87.6479      169.2  ...                                 NaN
# 1        -87.6479      169.2  ...                                 NaN
# 2        -87.6479      169.2  ...                                 NaN
# 3        -87.6479      169.2  ...                                 NaN
# 4        -87.6479      169.2  ...                                 NaN
# ...           ...        ...  ...                                 ...
# 592558   -87.6479      169.2  ...                                 NaN
# 592559   -87.6479      169.2  ...                                 NaN
# 592560   -87.6479      169.2  ...                                 NaN
# 592561   -87.6479      169.2  ...                                 NaN
# 592562   -87.6479      169.2  ...                                 NaN
#
#         precipitation_24_hour_Report_Type precipitation_24_hour_Source_Code  \
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                     NaN                               NaN
# 4                                     NaN                               NaN
# ...                                   ...                               ...
# 592558                                NaN                               NaN
# 592559                                NaN                               NaN
# 592560                                NaN                               NaN
# 592561                                NaN                               NaN
# 592562                                NaN                               NaN
#
#         precipitation_24_hour_Source_Station_ID  remarks  \
# 0                                           NaN      NaN
# 1                                           NaN      NaN
# 2                                           NaN      NaN
# 3                                           NaN      NaN
# 4                                           NaN      NaN
# ...                                         ...      ...
# 592558                                      NaN      NaN
# 592559                                      NaN      NaN
# 592560                                      NaN      NaN
# 592561                                      NaN      NaN
# 592562                                      NaN      NaN
#
#         remarks_Measurement_Code  remarks_Quality_Code  remarks_Report_Type  \
# 0                            NaN                   NaN                  NaN
# 1                            NaN                   NaN                  NaN
# 2                            NaN                   NaN                  NaN
# 3                            NaN                   NaN                  NaN
# 4                            NaN                   NaN                  NaN
# ...                          ...                   ...                  ...
# 592558                       NaN                   NaN                  NaN
# 592559                       NaN                   NaN                  NaN
# 592560                       NaN                   NaN                  NaN
# 592561                       NaN                   NaN                  NaN
# 592562                       NaN                   NaN                  NaN
#
#        remarks_Source_Code  remarks_Source_Station_ID
# 0                      NaN                        NaN
# 1                      NaN                        NaN
# 2                      NaN                        NaN
# 3                      NaN                        NaN
# 4                      NaN                        NaN
# ...                    ...                        ...
# 592558                 NaN                        NaN
# 592559                 NaN                        NaN
# 592560                 NaN                        NaN
# 592561                 NaN                        NaN
# 592562                 NaN                        NaN
#
# [592563 rows x 238 columns]

# %%
len(sorted_station_ids)
# Out:
# 80

# %%
tmp_station = []

def has_over_500_non_nans(lst):
    # count how many entries are NOT np.nan
    n_non_nan = sum(1 for x in lst if not np.isnan(x))
    return n_non_nan > 500

for i, sid in enumerate(sorted_station_ids):
    try:
        if has_over_500_non_nans(data_by_station[i]["dew_point_temperature"]):
            tmp_station.append(data_by_station[i])
            print(sid)
        else:
